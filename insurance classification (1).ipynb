# %%
from google.colab import files
upload = file.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a4e538a163dc> in <module>()
# ----> 1 from google.colab import files
#       2 upload = file.upload()
#
# ModuleNotFoundError: No module named 'google'

# %%
import pandas as pd
dataframe = pd.read_csv('insurance.csv')

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
dataframe.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#data visualization:
import seaborn as sns

# %%
sns.pairplot(data = dataframe)

# %%
#FEATURES
features = dataframe[['bedrooms','bathrooms','sqft_living','view','grade','sqft_above','sqft_basement','yr_built','yr_renovated','zipcode','lat','long','sqft_living15'
,'sqft_lot15']]

# %%
#target = dataframe['grade']
target = dataframe['age']

# %%
#normalization
import matplotlib.pyplot as plt
plt.hist(target,bins=10)
# Out:
# (array([1.9021e+04, 2.1420e+03, 3.2200e+02, 9.0000e+01, 2.6000e+01,
#         4.0000e+00, 4.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([  75000.,  837500., 1600000., 2362500., 3125000., 3887500.,
#         4650000., 5412500., 6175000., 6937500., 7700000.]),
#  <a list of 10 Patch objects>)

# %%
#solving normalization
import numpy as np

# %%
#log trasformation
dataframe_norm = np.log(target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-38f560deb8d4> in <module>()
#       1 #log trasformation
# ----> 2 dataframe_norm = np.log(target)
#
# NameError: name 'np' is not defined

# %%
plt.hist(dataframe_norm)
# Out:
# (array([6.300e+01, 5.330e+02, 3.977e+03, 7.183e+03, 6.345e+03, 2.533e+03,
#         7.410e+02, 1.930e+02, 3.800e+01, 7.000e+00]),
#  array([11.22524339, 11.68839214, 12.15154089, 12.61468964, 13.07783839,
#         13.54098714, 14.00413589, 14.46728464, 14.93043339, 15.39358214,
#         15.85673089]),
#  <a list of 10 Patch objects>)

# %%
#dont apply normalization
#train test split
from sklearn.model_selection import train_test_split

# %%
#result with out normalization
x_train,x_test,y_train,y_test = train_test_split(features,target,test_size=0.2,train_size=0.8)

# %%
#performance matric
from sklearn.metrics import r2_score

# %%
#linear regression model
from sklearn.linear_model import LinearRegression

# %%
#Feeding the Model
regressor = LinearRegression()
reg_fit = regressor.fit(x_train,y_train)
reg_pred = reg_fit.predict(x_test)

# %%
#score 
score_not_norm = r2_score(y_test,reg_pred)

# %%
score_not_norm
# Out:
# 0.651842841769769

# %%
#result with normalization
x_train_n,x_test_n,y_train_n,y_test_n = train_test_split(features,dataframe_norm,test_size=0.2,train_size=0.8)

# %%
#feeding the model
regressor_n = LinearRegression()
reg_fit_n = regressor_n.fit(x_train_n,y_train_n)
reg_pred_n = reg_fit_n.predict(x_test_n)

# %%
score_norm = r2_score(y_test_n,reg_pred_n)

# %%
print(score_norm)
# Out:
# 0.7552842154495022

# %%
# Out:
#   File "<ipython-input-27-4a44d3affc94>", line 5
#     y='count()',h)
#                ^
# SyntaxError: positional argument follows keyword argument
